# %% [markdown]
# # 📊 Análise de Vendas de E-commerce
#
# Notebook de análise exploratória de vendas com Python. Gera os dados e o mini-dashboard de gráficos.

# %% [markdown]
# ## 1. Execução do pipeline

# %%
# %run src/01_gerar_dados.py
# Out:
# Gerado: 20000 pedidos | receita total = R$ 31,853,073
# CSV e SQLite salvos em C:\Users\kalux\OneDrive\Área de Trabalho\portfolio-dados\3-analise-vendas\dados

# %%
# %run src/02_analise.py
# Out:
# == KPIs ==
# Receita total:  R$ 31,853,073
# Ticket médio:   R$ 1,592.65
# Nº de pedidos:  20,000
# C:\Users\kalux\OneDrive\Área de Trabalho\portfolio-dados\3-analise-vendas\src\02_analise.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cat.values, y=cat.index, ax=ax, palette="mako")
# Ticket médio por canal:
# canal
# Site           1579.27
# App            1588.74
# Marketplace    1617.78
#
# Dashboard salvo em C:\Users\kalux\OneDrive\Área de Trabalho\portfolio-dados\3-analise-vendas\imagens

# %% [markdown]
# ## 2. Resultados visuais

# %%
from IPython.display import Image, display
display(Image("imagens/receita_mensal.png"))
display(Image("imagens/receita_categoria.png"))
display(Image("imagens/regiao_canal.png"))
